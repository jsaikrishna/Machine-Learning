# %% [markdown]
# # Learning Theory Homework
# ***
# **Name**: Saikrishna Jaliparthy
# ***
#
# This assignment is due on Moodle by **5pm on Friday March 9th**. Submit only this Jupyter notebook to Moodle. Do not compress it using tar, rar, zip, etc. Your solutions to analysis questions should be done in Markdown directly below the associated question.  Remember that you are encouraged to discuss the problems with your instructors and classmates, but **you must write all code and solutions on your own**.  For a refresher on the course **Collaboration Policy** click [here](https://github.com/chrisketelsen/CSCI5622-Machine-Learning/blob/master/resources/syllabus.md#collaboration-policy)

# %% [markdown]
# ## Overview
# ***
#
# In this assignment you will explore the concepts of PAC learnability and VC dimension.

# %% [markdown]
# ### [15 points] Problem 1:
# ***
#
# Consider the class C of concepts defined by triangles with **distinct** vertices of the form $(i, j)$ where $i$ and $j$ are integers in the interval $[0,99]$. A concept c labels points on the interior and boundary of the associated triangle as positive and points exterior to the triangle as negative.
#
# **Note**: To make life easier, we'll allow degenerate triangles in $C$. That is, triangles where the vertices are collinear. The following image depicts an example of a nondegenerate and a degenerate triangle.

# %% [markdown]
# <img src="figs/triangles.png" width=400 height=50>

# %% [markdown]
# **Part A**: Suppose we have an algorithm that produces a consistent $h$ from the hypothesis class $H = C$. Give a bound on the number of training examples sufficient to assure that for any target concept $c$ in $C$, our algorithm will, with probability $1-\delta$, output a hypothesis $h$ with generalization error at most $\epsilon$.

# %% [markdown]
# ** Solution**
#
# According to the given condition it is a finite consistent hypothesis class, So the bound on the numbe rof training examples is:

# %% [markdown]
# $$
# m \geq \frac{1}{\epsilon}\left(\ln\left| H \right| + \ln\frac{1}{\delta} \right)
# $$

# %% [markdown]
# **Part B**: Based on your bound in **Part A**, determine the minimum number of training examples necessary such that for any target concept $c$ in $C$, our algorithm will, with probability $0.95$, output a hypothesis $h$ with generalization error at most $0.15$.

# %% [markdown]
# ** Solution **
#
# Given the generalization error is 0.15 then epsilon= 0.15 and probability is 0.95 then delta=0.05.
#
# Cardinality of hypothesis H is choosing 3 points in the space of points which has 10,000 points
# $$
# |H| = {{100*100}\choose{3}}  =  166616670000
# $$
#
# Using the above formulae of bound on number of training examples
#
# $$
# m \geq \frac{1}{\epsilon}\left(\ln\left| H \right| + \ln\frac{1}{\delta} \right)
# $$
#
# $$
# m \geq  \frac{1}{0.15}\left(\ln\left( 166616670000 \right) + \ln\frac{1}{0.05} \right)
# $$
#
# $$
# m \geq  \frac{1}{0.15}\left(25.8389616217 + 2.99573227355 \right)  \approx 192.231
# $$
#
# So we can specify that we'll achieve our accuracy and confidence goals with $m \geq 193$ training examples

# %% [markdown]
# ### [15 points] Problem 2:
# ***
#
# Consider feature vectors that live in two-dimensional space and the class of hypotheses defined by circles **centered at the origin**. There are two different kinds of hypotheses $h$ in this class. One type of hypthesis classifies points as positive if they lie on the boundary or **interior** of the circle, and negative otherwise. The other type of hypothesis classifies points as positive if they lie on the boundary or **exterior** of the circle, and negative otherwise. State and prove (rigorously) the VC dimension of this family of classifiers.

# %%
import matplotlib.pylab as plt
# %matplotlib inline

mycolors = {"blue":"steelblue", "red":"#a76c6e",  "green":"#6a9373", "smoke":"#f2f2f2"}
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(20,4))

circle1=plt.Circle((0,0),6,fill=False)
circle2=plt.Circle((0,0),6,fill=False)
circle3=plt.Circle((0,0),4,fill=False)
circle4=plt.Circle((0,0),4,fill=False)

axes[0].add_patch(circle1)
axes[0].scatter([3,2], [4,3], color=[mycolors["red"], mycolors["red"]], s=150)
#axes[0].plot([0,5], [0,2], color=mycolors["red"], ls="--")
axes[0].set_xlim([-10,10]); axes[0].set_ylim([-6,6]); axes[0].grid(alpha=0.25)

axes[1].add_patch(circle2)
axes[1].scatter([3,2], [4,3], color=[mycolors["blue"], mycolors["blue"]], s=150)
#axes[1].plot([0,2], [0,5], color=mycolors["red"], ls="--")
axes[1].set_xlim([-10,10]); axes[1].set_ylim([-6,6]); axes[1].grid(alpha=0.25)

axes[2].add_patch(circle3)
axes[2].scatter([3,2], [4,3], color=[mycolors["red"], mycolors["blue"]], s=150)
#axes[2].plot([0,5], [0,5], color=mycolors["red"], ls="--")
axes[2].set_xlim([-10,10]); axes[2].set_ylim([-6,6]); axes[2].grid(alpha=0.25)

axes[3].add_patch(circle4)
axes[3].scatter([3,2], [4,3], color=[mycolors["blue"], mycolors["red"]], s=150)
#axes[3].plot([0,5], [0,5], color=mycolors["red"], ls="--")
axes[3].set_xlim([-10,10]); axes[3].set_ylim([-6,6]); axes[3].grid(alpha=0.25)

# %% [markdown]
# By observing the above plots we can say that the VC Dimension $\geq$ 2.
#
# From the Above we can observe that 1st and 4th figure replicates the type of hypothesis that classifies points as positive if they lie on the boundary or **interior** of the circle, and negative otherwise.
#
# From the Above we can observe that the 2nd and 3rd figure replicates the type of hypothesis that classifies points as positive if they lie on the boundary or **exterior** of the circle, and negative otherwise.
#
# Now we show that we can't shatter any set of $3$ points.  Notice that in determining the decision boundary, the only thing matters is the radius of the cirlce.
#
# Consider three points ${\bf x}_1, {\bf x}_2$, and ${\bf x}_3$ with associated distances are  $r_1, r_2,$ and $r_3$ from center. Without loss of generality, order them such that $r_1 \leq r_2 \leq r_3$. Our classifier can be defined by the decision rule $y_k = h_t(r_k) = 1$ if $r_k \leq t$ and $-1$ otherwise.   Now consider the labeling of the three points such that $y_1 = +1$, $y_2 = -1$, and $y_3 = +1$.  If our classifier captures this dichotomy then we must have both $r_1 \leq t$ and $r_3 \leq t$ since they are positively labeled.  This then gives us $r_1 \leq r_2 \leq r_3 \leq t$.  But this is a contradiction because $y_2 = -1$.
#
# A similar argument shows that the hypothesis $y_k = h_t(r_k) = 1$ if $r_k \geq t$ and $-1$ otherwise is insufficient to handle 3 points.
#
# Thus, no collection of 3 points can be shattered. we can say that VC Dimension < 3
#
# So, The VC Dimension is 2

# %% [markdown]
# ### [20 points] Problem 3: Empirical Verification of PAC Bounds for Axis-Aligned Rectangles
# ***
#
# In the in-class notebook associated with PAC Learnability, we proved a PAC bound for the class of concepts $C$ comprised of axis-aligned rectangles living in $\mathbb{R}^2$ of the form $(a \leq x \leq b) \wedge (c \leq y \leq d)$ where $a, b, c, d$ are real numbers. Specifically, we proved that with probability $1-\delta$, any consistent learner could learn a hypothesis $h$ in $H = C$ with generalization error less than $\epsilon$ provided that the number of training examples satisfied
#
# $$
# m > \frac{4}{\epsilon}\log\frac{4}{\delta}
# $$
#
# In this problem you will empirically verify this bound for the restricted concept class $C$ where the rectangles are defined by $(a \leq x \leq b) \wedge (c \leq y \leq d)$ where $a, b, c, d$ are real numbers satisfying $0 \leq a \leq b \leq 100$ and $0 \leq c \leq d \leq 100$.
#
# **Part A**: The following is a general outline of how you should accomplish this, but it is up to you how you organize your code.

# %% [markdown]
# - Write some code that randomly generates a concept rectangle $c$.
#
#
#
# - Write some code that, given feature vectors of length-2, labels them according to some rectangle (that is, labels a point positive if the point is on the boundary or interior of the rectangle, and negative otherwise).
#
#
#
# - Write some code that, given training examples of length-2, and labeled according to a concept $c$, returns a consistent hypothesis rectangle $h$.
#
#
#
# - Write some code that generates a training set of size $m$, labels them according to a random concept $c$, learns a consistent hypothesis $h$, and then approximates the generalization error by predicting on $1000$ new examples from the same distribution as the training data.
#
#
# - Write some code that computes approximate generalization errors for $100$ independent concepts $c$ and associated training sets of size $m$, and returns the worst-case generalization error at the confidence level $1-\delta$.  One way to do this in the case that say $\delta = 0.05$, is to report the $95^\textrm{th}$ percentile of the $100$ samples of the generalization error. We can then say that, in our simulation, $100(1-\delta)\%$ of our observed generalization errors were less than our computed value. (**Bonus**: If your code is efficient, try increasing the number of runs in the simulation to $500$. This should give you a better approximation of the generalization error.)

# %%
import random
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
class values:
    def __init__(self, l, b):
        self.l=l
        self.b=b

# %%
class PAC:
    def __init__(self):
        return
        
    def generate(self,m_size):
        # Randomly Generating the Data
        td=[]
        for i in range(m_size):
            x=random.uniform(0,100)
            y=random.uniform(0,100)
            td.append(values(x,y))
        return td
    
    def gerror(self,co_te_labels,hy_tr_labels):
        # Calculating the Error
        x=0
        for k in range(len(co_te_labels)):
            if co_te_labels[k] != hy_tr_labels[k]:
                x=x+1
        return x/len(co_te_labels)
        
    def concept(self):
        #Defining Concept
        ca=[]
        ca1=random.uniform(0,100)
        ca.append(ca1)
        ca2=random.uniform(0,100)
        ca.append(ca2)
        ca3=random.uniform(0,100)
        ca.append(ca3)
        ca4=random.uniform(0,100)
        ca.append(ca4)
        
        ca.sort()
        self.con=[values(ca[0],ca[2]),values(ca[1],ca[3])]
        
    def label(self, fv, edge):
        #Defining the label based on given Values and Concept
        if fv.l>= edge[0].l and fv.l <=edge[1].l and fv.b>= edge[0].b and fv.b <=edge[1].b:
            return 1
        else:
            return -1
    
    def consistent_hypothesis(self,td):
        # Hypothesis
        l_l = float('inf')
        l_b = float('inf')
        g_l = float('-inf')
        g_b = float('-inf')
        for w in td:
            if self.label(w, self.con) == 1:
                if w.l > g_l:
                    g_l = w.l
                if w.l < l_l:
                    l_l = w.l
                if w.b > g_b:
                    g_b = w.b
                if w.b < l_b:
                    l_b = w.b 
        self.hyp = [values(l_l, l_b) , values(g_l, g_b)]
        
    
    def heart(self,ind_con,train_size,test_size,delta):
        worstcase_gen_error=[]
        for ms in train_size:
            gen_er=[]
            for id in range(ind_con):
                self.concept()
                
                train_data=self.generate(ms)
                self.consistent_hypothesis(train_data)
                
                test_data=self.generate(test_size)
                
                #hypothesis Labels and Concept Labels was generating for Test_data
                
                hy_labels=[]
                for test in test_data:
                    hy_labels.append(self.label(test,self.hyp))
                    
                    
                co_labels=[]
                for test in test_data:
                    co_labels.append(self.label(test,self.con))
                    
                    # Generalization Error Calculation
                
                gen_error=self.gerror(co_labels,hy_labels)
                gen_er.append(gen_error)
                
                #Percentiled Valued Calculation of Error
            a=np.array(gen_er)
            a.sort()
            wc_gerror=np.percentile(a,100*(1-delta))
            worstcase_gen_error.append(wc_gerror)
        return worstcase_gen_error

# %%
p=PAC()
p.heart(100,[1,100],1000,0.05)
# Out:
# [0.092049999999999993, 0.044399999999999974]

# %% [markdown]
# **Part B**: Use your code to estimate the generalization error with confidence parameter $\delta=0.05$ for training sets of size $m$ where $m = 250, 500, 1000, 1250,$ and $1500$ and the data are comprised of points $(x,y)$ where the $x$- and $y$-values are sampled from the continuous uniform distribution $\textrm{unif}(0,100)$. Make a **log-log** plot with $m$ on the horizontal axes and $\epsilon$ on the vertical axis.  Additionally, overlay the theoretical PAC bound on your graph and discuss your results.

# %%
m=[250,500,1000,1250,1500]
delta=0.05

#Caluclating for Given M
out=p.heart(500,m,1000,delta)
print(m)
print(out)
plt.loglog(m,out,label='Practical',color='r')

#Calculating for the Given Theoritical PAC Bound
out1=[]
for z in m:
    out1.append((4/z)* math.log(4/delta))

plt.loglog(m,out1,label='PAC Bound m',color='green')
plt.xlabel('m')
plt.ylabel('Generalization Error')

plt.legend()
# Out:
# [250, 500, 1000, 1250, 1500]
# [0.025000000000000001, 0.012999999999999999, 0.0089999999999999993, 0.0070000000000000001, 0.0060000000000000001]

# %% [markdown]
# From the above graph the PAC Bound was derived using the formulae specified at the starting of the problem and then for practical/specified m the generalization error was calculated using the code above.
#
# we can observe that the as the number of m increase the difference of the generalization between PAC Bound m and Practical decreases and the gap also decreases between the Practical and PAC Bound m.
#
# At large value of m the practical/Generalization error increases at one point and then decreases slightly but not rapidly but for the PAC Bound m it is  in the consistent manner with out any disrupt changes.

# %% [markdown]
# **Part C**: Repeat **Part B** where the data are comprised of points $(x,y)$ where the $x$- and $y$-values are sampled from the normal distribution with mean $\mu = 50$ and standard deviation $\sigma = 25$. Again, overlay the theoretical PAC bound on your graph and discuss your results. Do you expect to observe very different results than those observed in **Part B**?

# %%
import numpy as np
import random

# %%
class PAC:
    def __init__(self):
        return
        
    def generate(self,m_size):
        # Randomly Generating the Data
        td=[]
        for i in range(m_size):
            x=np.random.normal(50,25)
            y=np.random.normal(50,25)
            td.append(values(x,y))
        return td
    
    def gerror(self,co_te_labels,hy_tr_labels):
        # Calculating the Error
        x=0
        for k in range(len(co_te_labels)):
            if co_te_labels[k] != hy_tr_labels[k]:
                x=x+1
        return x/len(co_te_labels)
        
    def concept(self):
        #Defining Concept
        ca=[]
        ca1=random.uniform(0,100)
        ca.append(ca1)
        ca2=random.uniform(0,100)
        ca.append(ca2)
        ca3=random.uniform(0,100)
        ca.append(ca3)
        ca4=random.uniform(0,100)
        ca.append(ca4)
        
        ca.sort()
        self.con=[values(ca[0],ca[2]),values(ca[1],ca[3])]
        
    def label(self, fv, edge):
        #Defining the label based on given Values and Concept
        if fv.l>= edge[0].l and fv.l <=edge[1].l and fv.b>= edge[0].b and fv.b <=edge[1].b:
            return 1
        else:
            return -1
    
    def consistent_hypothesis(self,td):
        # Hypothesis
        l_l = float('inf')
        l_b = float('inf')
        g_l = float('-inf')
        g_b = float('-inf')
        for w in td:
            if self.label(w, self.con) == 1:
                if w.l > g_l:
                    g_l = w.l
                if w.l < l_l:
                    l_l = w.l
                if w.b > g_b:
                    g_b = w.b
                if w.b < l_b:
                    l_b = w.b 
        self.hyp = [values(l_l, l_b) , values(g_l, g_b)]
        
    
    def heart(self,ind_con,train_size,test_size,delta):
        worstcase_gen_error=[]
        for ms in train_size:
            gen_er=[]
            for id in range(ind_con):
                self.concept()
                
                train_data=self.generate(ms)
                self.consistent_hypothesis(train_data)
                
                test_data=self.generate(test_size)
                
                #hypothesis Labels and Concept Labels was generating for Test_data
                
                hy_labels=[]
                for test in test_data:
                    hy_labels.append(self.label(test,self.hyp))
                    
                    
                co_labels=[]
                for test in test_data:
                    co_labels.append(self.label(test,self.con))
                    
                    # Generalization Error Calculation
                
                gen_error=self.gerror(co_labels,hy_labels)
                gen_er.append(gen_error)
                
                #Percentiled Valued Calculation of Error
            a=np.array(gen_er)
            a.sort()
            wc_gerror=np.percentile(a,100*(1-delta))
            worstcase_gen_error.append(wc_gerror)
        return worstcase_gen_error

# %%
p=PAC()
p.heart(100,[1,100],1000,0.05)

m=[250,500,1000,1250,1500]
delta=0.05

#Caluclating for Given M
out=p.heart(500,m,1000,delta)
print(m)
print(out)
plt.loglog(m,out,label='Practical', color='r')

#Calculating for the Given Theoritical PAC Bound
out1=[]
for z in m:
    out1.append((4/z)* math.log(4/delta))

plt.loglog(m,out1,label='PAC Bound m',color='green')
plt.xlabel('m')
plt.ylabel('Generalization Error')

plt.legend()
# Out:
# [250, 500, 1000, 1250, 1500]
# [0.025000000000000001, 0.014, 0.0080000000000000002, 0.0060000000000000001, 0.0060000000000000001]

# %% [markdown]
# From the above graph the PAC Bound was derived using the formulae specified at the starting of the problem and then for practical/specified m the generalization error was calculated using the code above.
#
# we can observe that the as the number of m increase the difference of the generalization between PAC Bound m and Practical decreases and the gap also decreases between the Practical and PAC Bound m.
#
# For Normal Distribution At large value of m the practical/Generalization error increases at one point and then decreases slightly and rapidly and it becomes constant but for the PAC Bound m it is  in the consistent manner with out any disrupt changes.
#
# But for the Uniform Distribution There is no rapid decrease in the Generlaization Error of the practical and even PAC Bound m is also consistent.
